# %%
pip install pandas mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import mysql.connector

# %%
pip install sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
'''1. Load Data from SQL  
Use pandas.read_sql() to pull the orders, order_items, and customers tables into a DataFrame.'''

from sqlalchemy import create_engine
import pandas as pd

engine = create_engine(
    "mysql+pymysql://root:Jeevi%402004@localhost/retail_sales"
)
customers_df   = pd.read_sql("SELECT * FROM customers;", engine)
stores_df      = pd.read_sql("SELECT * FROM stores;", engine)
staffs_df      = pd.read_sql("SELECT * FROM staffs;", engine)
categories_df  = pd.read_sql("SELECT * FROM categories;", engine)
brands_df      = pd.read_sql("SELECT * FROM brands;", engine)
products_df    = pd.read_sql("SELECT * FROM products;", engine)
orders_df      = pd.read_sql("SELECT * FROM orders;", engine)
order_items_df = pd.read_sql("SELECT * FROM order_items;", engine)
stocks_df      = pd.read_sql("SELECT * FROM stocks;", engine)
# customers_df calling table

# %%
'''
#Optional: check row counts
print("Customers:", len(customers_df)) #or
("Customers:", len(customers_df))
("Stores:", len(stores_df))
("Staffs:", len(staffs_df))
("Categories:", len(categories_df))
("Brands:", len(brands_df))
("Products:", len(products_df))
("Orders:", len(orders_df))
("Order Items:", len(order_items_df))
("Stocks:", len(stocks_df)) '''
# Out:
# '\n#Optional: check row counts\nprint("Customers:", len(customers_df)) #or\n("Customers:", len(customers_df))\n("Stores:", len(stores_df))\n("Staffs:", len(staffs_df))\n("Categories:", len(categories_df))\n("Brands:", len(brands_df))\n("Products:", len(products_df))\n("Orders:", len(orders_df))\n("Order Items:", len(order_items_df))\n("Stocks:", len(stocks_df)) '

# %%
'''2. Basic EDA (Exploratory Data Analysis) 
Use df.describe(), df.info(), and df.value_counts() to summarize the 
dataset.'''
# Out:
# '2. Basic EDA (Exploratory Data Analysis) \nUse df.describe(), df.info(), and df.value_counts() to summarize the \ndataset.'

# %%
# Structure & Data Types → df.info()
customers_df.info()
stores_df.info()
staffs_df.info()
categories_df.info()
brands_df.info()
products_df.info()
orders_df.info()
order_items_df.info()
stocks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1445 non-null   int64
#  1   first_name   1445 non-null   object
#  2   last_name    1445 non-null   object
#  3   phone        1445 non-null   object
#  4   email        1445 non-null   object
#  5   street       1445 non-null   object
#  6   city         1445 non-null   object
#  7   state        1445 non-null   object
#  8   zip_code     1445 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 101.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   store_id    3 non-null      int64
#  1   store_name  3 non-null      object
#  2   phone       3 non-null      object
#  3   email       3 non-null      object
# ...

# %%
# Statistical Summary → df.describe()
customers_df.describe()
# Out:
#        customer_id
# count  1445.000000
# mean    723.000000
# std     417.279882
# min       1.000000
# 25%     362.000000
# 50%     723.000000
# 75%    1084.000000
# max    1445.000000

# %%
stores_df.describe()
# Out:
#        store_id
# count       3.0
# mean        2.0
# std         1.0
# min         1.0
# 25%         1.5
# 50%         2.0
# 75%         2.5
# max         3.0

# %%
staffs_df.describe()
# Out:
#         staff_id  active  store_id  manager_id
# count   9.000000     9.0  9.000000    9.000000
# mean    6.000000     1.0  2.000000    3.444444
# std     2.738613     0.0  0.866025    2.554952
# min     2.000000     1.0  1.000000    1.000000
# 25%     4.000000     1.0  1.000000    1.000000
# 50%     6.000000     1.0  2.000000    2.000000
# 75%     8.000000     1.0  3.000000    5.000000
# max    10.000000     1.0  3.000000    7.000000

# %%
categories_df.describe()
# Out:
#        category_id
# count     7.000000
# mean      4.000000
# std       2.160247
# min       1.000000
# 25%       2.500000
# 50%       4.000000
# 75%       5.500000
# max       7.000000

# %%
brands_df.describe()
# Out:
#        brand_id
# count  9.000000
# mean   5.000000
# std    2.738613
# min    1.000000
# 25%    3.000000
# 50%    5.000000
# 75%    7.000000
# max    9.000000

# %%
products_df.describe()
# Out:
#        product_id    brand_id  category_id   model_year    list_price
# count  321.000000  321.000000   321.000000   321.000000    321.000000
# mean   161.000000    5.476636     4.028037  2017.591900   1520.591402
# std     92.808944    3.708131     2.188569     0.665063   1612.152765
# min      1.000000    1.000000     1.000000  2016.000000     89.990000
# 25%     81.000000    1.000000     2.000000  2017.000000    439.990000
# 50%    161.000000    7.000000     3.000000  2018.000000    761.990000
# 75%    241.000000    9.000000     6.000000  2018.000000   2299.990000
# max    321.000000    9.000000     7.000000  2019.000000  11999.990000

# %%
orders_df.describe()
# Out:
#           order_id  customer_id  order_status     store_id     staff_id
# count  1615.000000  1615.000000   1615.000000  1615.000000  1615.000000
# mean    808.000000   654.171517      3.778947     1.892260     5.855108
# std     466.354658   443.229967      0.693430     0.558395     1.913899
# min       1.000000     1.000000      1.000000     1.000000     2.000000
# 25%     404.500000   237.000000      4.000000     2.000000     6.000000
# 50%     808.000000   638.000000      4.000000     2.000000     6.000000
# 75%    1211.500000  1041.500000      4.000000     2.000000     7.000000
# max    1615.000000  1445.000000      4.000000     3.000000     9.000000

# %%
order_items_df.describe()
# Out:
#           order_id      item_id   product_id  category_id     quantity  \
# count  4214.000000  4214.000000  4214.000000  4214.000000  4214.000000
# mean    752.235406     2.255339    49.791647     3.747034     1.499288
# std     426.803369     1.192115    56.092488     1.970488     0.500059
# min       1.000000     1.000000     2.000000     1.000000     1.000000
# 25%     386.000000     1.000000    13.000000     2.000000     1.000000
# 50%     762.500000     2.000000    25.000000     3.000000     1.000000
# 75%    1123.750000     3.000000    73.000000     6.000000     2.000000
# max    1478.000000     5.000000   313.000000     7.000000     2.000000
#
#          list_price     discount   total_price
# count   4214.000000  4214.000000   4214.000000
# mean    1179.374791     0.105629   1764.965577
# std     1312.889094     0.058311   2161.356375
# min       89.990000     0.050000     89.790000
# 25%      429.000000     0.050000    539.780000
# ...

# %%
stocks_df.describe()
# Out:
#          store_id  product_id    quantity
# count  622.000000  622.000000  622.000000
# mean     2.004823  156.461415   16.905145
# std      0.813519   91.050786   25.575735
# min      1.000000    1.000000    0.000000
# 25%      1.000000   78.000000    7.000000
# 50%      2.000000  156.500000   14.000000
# 75%      3.000000  236.750000   22.000000
# max      3.000000  313.000000  304.000000

# %%
# Frequency Analysis → value_counts()
# Orders
orders_df['status_order'].value_counts()
#orders_df['store_id'].value_counts()
#orders_df['staff_id'].value_counts()
# Out:
# status_order
# Delivered    987
# Shipped      458
# Pending      170
# Name: count, dtype: int64

# %%
# Order Items
order_items_df['product_id'].value_counts()#.head() #need use
order_items_df['category_id'].value_counts()
# Out:
# category_id
# 3    1244
# 6    1081
# 1     694
# 2     486
# 7     300
# 4     239
# 5     170
# Name: count, dtype: int64

# %%
# Products
products_df['brand_id'].value_counts()
products_df['category_id'].value_counts()
# Out:
# category_id
# 3    78
# 7    60
# 6    60
# 1    59
# 2    30
# 5    24
# 4    10
# Name: count, dtype: int64

# %%
# Staffs
staffs_df['active'].value_counts()
# Out:
# active
# 1    9
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
#Order Status Distribution
plt.figure(figsize=(6,4))
orders_df['status_order'].value_counts().plot(kind='bar', color='lightpink')
plt.title("Orders by Status")
plt.xlabel("Order Status")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
#Top 10 Products by Quantity Sold
plt.figure(figsize=(5,5))

(
    order_items_df
    .groupby('product_id')['quantity']
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .plot(kind='barh', color='lightblue')
)

plt.title("Top 10 Products by Quantity Sold")
plt.xlabel("Total Quantity Sold")
plt.ylabel("Product ID")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
#Customers by State
plt.figure(figsize=(4,4))
customers_df['state'].value_counts().head(6).plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90
)

plt.title("Customer Distribution by State (Top 6)")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
# understand
orders_df['order_date'] = pd.to_datetime(orders_df['order_date'])
ref_date = orders_df['order_date'].max()

rfm = (
    orders_df
    .merge(order_items_df, on='order_id')
    .groupby('customer_id')
    .agg(
        Recency=('order_date', lambda x: (ref_date - x.max()).days),
        Frequency=('order_id','nunique'),
        Monetary=('total_price', 'sum')
    )
    .reset_index()
)

rfm.head()
# Out:
#    customer_id  Recency  Frequency  Monetary
# 0            1     8036          1   9937.53
# 1            2     3774          1   4893.46
# 2            3     1735          1  17199.77
# 3            4     9069          1  11499.72
# 4            5     2587          1   5899.83

# %%
orders_df['order_date'] = pd.to_datetime(orders_df['order_date'])
reference_date = orders_df['order_date'].max()
recency_df = (
    orders_df
    .groupby('customer_id')['order_date']
    .max()
    .reset_index()
)

recency_df['Recency'] = (reference_date - recency_df['order_date']).dt.days
recency_df = recency
    
    .reset_index()
    .rename(columns={'total_price': 'Monetary'})
)
rfm_df = recency_df.merge(frequency_df, on='customer_id')
rfm_df = rfm_df.merge(monetary_df, on='customer_id')
rfm_df.head()
# Out:
#    customer_id  Recency  Frequency  Monetary
# 0            1     4777          3   9937.53
# 1            2     3774          3   4893.46
# 2            3     1735          3  17199.77
# 3            4     3682          3  11499.72
# 4            5     2587          3   5899.83

# %%
rfm_df
# Out:
#       customer_id  Recency  Frequency  Monetary
# 0               1     4777          3   9937.53
# 1               2     3774          3   4893.46
# 2               3     1735          3  17199.77
# 3               4     3682          3  11499.72
# 4               5     2587          3   5899.83
# ...           ...      ...        ...       ...
# 1440         1441     2159          1  10497.61
# 1441         1442      518          1   7841.32
# 1442         1443     5875          1  11237.59
# 1443         1444     4018          1   1749.57
# 1444         1445     9040          1   9999.78
#
# [1445 rows x 4 columns]

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:Jeevi%402004@localhost/retail_sales"
)
rfm_df.to_sql(
    name='customer_segments',
    con=engine,
    if_exists='replace',   # use 'append' if table already exists
    index=False
)
# Out:
# 1445
